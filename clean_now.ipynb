# %%
import pandas as pd 
import sqlalchemy

# %%
df1 = pd.read_csv('usa_sales.csv')
df2 = pd.read_csv('canada_sales.csv')

# %% [markdown]
# **USA**

# %%
df1.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   236670            Wired Headphones                2      11.99
# 1   236671  Bose SoundSport Headphones                1      99.99
# 2   236672                      iPhone                1      700.0
# 3   236673       AA Batteries (4-pack)                2       3.84
# 4   236674       AA Batteries (4-pack)                2       3.84
#
#        Order Date                      Purchase Address
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12011 entries, 0 to 12010
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          11983 non-null  object
#  1   Product           11983 non-null  object
#  2   Quantity Ordered  11983 non-null  object
#  3   Price Each        11983 non-null  object
#  4   Order Date        11983 non-null  object
#  5   Purchase Address  11983 non-null  object
# dtypes: object(6)
# memory usage: 563.1+ KB

# %%
df1.isnull().sum()
# Out:
# Order ID            28
# Product             28
# Quantity Ordered    28
# Price Each          28
# Order Date          28
# Purchase Address    28
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 43

# %%
df1 = df1.drop_duplicates()
df1.duplicated().sum()
# Out:
# 0

# %%
df1['Price Each'] = pd.to_numeric(df1['Price Each'], errors='coerce')  # ensures numeric values
df1['Price Each'] = df1['Price Each'].fillna(0).round().astype(int)   # handle NaN, then round

# %%
df1.head()
# Out:
#   Order ID                     Product Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                2          12
# 1   236671  Bose SoundSport Headphones                1         100
# 2   236672                      iPhone                1         700
# 3   236673       AA Batteries (4-pack)                2           4
# 4   236674       AA Batteries (4-pack)                2           4
#
#        Order Date                      Purchase Address
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001

# %% [markdown]
# **CANADA**

# %%
df2.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date         Purchase Address
# 0  04/19/19 08:46  128 Elm St, Quebec City
# 1             NaN       113 Oak St, Ottawa
# 2  04/07/19 22:30     116 Elm St, Winnipeg
# 3  04/12/19 14:38   149 Broadway, Edmonton
# 4  04/12/19 14:38  121 Maple St, Vancouver

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18383 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %%
df2.isnull().sum()
# Out:
# Order ID            59
# Product             59
# Quantity Ordered    59
# Price Each          59
# Order Date          59
# Purchase Address     0
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2['Price Each'] = pd.to_numeric(df2['Price Each'], errors='coerce')  # ensures numeric values
df2['Price Each'] = df2['Price Each'].fillna(0).round().astype(int)   # handle NaN, then round

# %%
exchange_rate = 1.25
df2['price_usd'] = df2['Price Each'] * exchange_rate

# %%
df2.head()
# Out:
#   Order ID                     Product Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                2          12
# 2   176559  Bose SoundSport Headphones                1         100
# 3   176560                Google Phone                1         600
# 4   176560            Wired Headphones                1          12
# 5   176561            Wired Headphones                1          12
#
#        Order Date          Purchase Address  price_usd
# 0  04/19/19 08:46   128 Elm St, Quebec City       15.0
# 2  04/07/19 22:30      116 Elm St, Winnipeg      125.0
# 3  04/12/19 14:38    149 Broadway, Edmonton      750.0
# 4  04/12/19 14:38   121 Maple St, Vancouver       15.0
# 5  04/30/19 09:27  123 Cedar Ave, Vancouver       15.0

# %% [markdown]
# **Merged**

# %%
merged_df= pd.concat([df1, df2], ignore_index=True)
merged_df.head()
# Out:
#   Order ID                     Product Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                2          12
# 1   236671  Bose SoundSport Headphones                1         100
# 2   236672                      iPhone                1         700
# 3   236673       AA Batteries (4-pack)                2           4
# 4   236674       AA Batteries (4-pack)                2           4
#
#        Order Date                      Purchase Address  price_usd
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101        NaN
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001        NaN
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035        NaN
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001        NaN
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001        NaN

# %%
df1.shape
# Out:
# (11940, 6)

# %%
df2.shape
# Out:
# (18324, 6)

# %%
merged_df.shape
# Out:
# (30264, 6)

# %%
exchange_rate= 1.25
merged_df['price_usd'] = merged_df['Price Each'] * exchange_rate

# %%
merged_df.head()
# Out:
#   Order ID                     Product Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                2          12
# 1   236671  Bose SoundSport Headphones                1         100
# 2   236672                      iPhone                1         700
# 3   236673       AA Batteries (4-pack)                2           4
# 4   236674       AA Batteries (4-pack)                2           4
#
#        Order Date                      Purchase Address  price_usd
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101       15.0
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001      125.0
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035      875.0
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001        5.0
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001        5.0

# %%
merged_df['price_usd'] = pd.to_numeric(merged_df['price_usd'], errors='coerce')  # ensures numeric values
merged_df['price_usd'] = merged_df['price_usd'].fillna(0).round().astype(int)   # handle NaN, then round

# %%
merged_df.head()
# Out:
#   Order ID                     Product Quantity Ordered  Price Each  \
# 0   236670            Wired Headphones                2          12
# 1   236671  Bose SoundSport Headphones                1         100
# 2   236672                      iPhone                1         700
# 3   236673       AA Batteries (4-pack)                2           4
# 4   236674       AA Batteries (4-pack)                2           4
#
#        Order Date                      Purchase Address  price_usd
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101         15
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001        125
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035        875
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001          5
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001          5

# %%
db_url = "postgresql://exam_db_4zf2_user:hCxnd8Mr3VLMqRGyemkbEyBdHkmfBEgH@dpg-cvsrju9r0fns73dp1heg-a.oregon-postgres.render.com/exam_db_4zf2"
connection = sqlalchemy.create_engine(db_url)

merged_df.to_sql("sales_data", con=connection, if_exists="replace", index=False)

query = "SELECT * FROM sales_data LIMIT 5;"
result_df = pd.read_sql(query, con=connection)
result_df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3279 """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281 The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299 """
# -> 3300 return self.pool.connect()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
# ...

# %%
pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.2 MB 465.5 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.2 MB 653.6 kB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.2 MB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 0.6/1.2 MB 2.3 MB/s eta 0:00:01
#    --------------------------- ------------ 0.8/1.2 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 3.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
